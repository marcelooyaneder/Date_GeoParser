# %%
#!pip install pyproj
#!pip install request

# %% [markdown]
# # MANUAL SKETCHBOOK
#
# La finalidad de este software es completar la mayor cantidad de información del estandar Darwin Core a partir de un par de coordenadas, *importante hacer notar que este software hasta el momento no realiza ningun tipo de georreferenciación, solo rellena datos*, esto se realiza a partir de un set de coordenadas, esta pueden ser del campo verbatimCoordinates o decimalLatitude y decimalLongitude, pertenecientes al estandar. Con estos datos será completar los siguientes campos, si es que se encuentra la información necesaria.
#
# - higherGeography
# - continent
# - country
# - countryCode
# - stateProvince
# - county
# - municipality
# - decimalLongitude, decimalLatitude
# - geodeticDatum
# - coordinatePrecision
# - verbatimLatitude, verbatimLongitude
# - verbatimCoordinateSystem
#
# Hasta el momento no se ha podido probar la localización de localidades marinas, pero es un trabajo en progreso.
#
# Este script se divide en dos clases
#
# - Preparación de la base de datos (db_prep)
# - Transformación de coordenadas (coord_transform)
#
# ## Preparación de la base de datos
#
# Esta clase recibe el nombre de "db_prep" y necesita como entrada una base de datos con algunos componentes mínimos del estandar Darwin Core (DwC) para su realización.
#
#
#
# ## Transformación de coordenadas

# %% [markdown]
# - El campo verbatimCoordintes debe tener las coordenadas en el siguiente formato (dejar en georeferenceRemarks las coordenadas como vienen en su etiqueta original)
#         -En el caso de coordenadas en grados minutos y segundos gg°mm'ss" S, gg°mm'ss" W o gg°mm'ss" N, gg°mm'ss" E la importancia radica que debes estar separadas por una coma, misma situación para grados y minutos decimales
#         -En el caso de UTM deben ser escritas de la siguiente forma 308617 6272156 19S, la importancia esta que se encuentren separadas por espacio.

# %%
#from pyproj import Proj #no se está usando por el momento
import utm
import requests
import json
import pandas as pd
import numpy as np
import math
import re
from GeoParser import *
#from geopy.geocoders import Nominatim #FASTER than api



pd.set_option('display.max_columns', None)  # or 1000
pd.set_option('display.max_rows', None)  # or 1000
pd.set_option('display.max_colwidth', None)  # or 199

# %% [markdown]
# country_data=pd.read_csv("https://raw.githubusercontent.com/VertNet/DwCVocabs/master/vocabs/countryCode_country_continent_merged.csv")
# country_data.set_index("country",inplace=True)
# country_data_dict=country_data.to_dict()

# %%
class db_prep:
    def __init__(self,data):
        self.data=data
    
    def verbatimCoordinates_dms_sep(self,index):
        """
        split verbatimCoordinates data and fill verbatimLatitude & verbatimLongitude
        """
        for Coordinate in self.data.loc[index,"verbatimCoordinates"].split(","):
            if "N" in Coordinate.upper(): 
                self.data.loc[index,"verbatimLatitude"]=Coordinate
            elif "S" in Coordinate.upper(): 
                self.data.loc[index,"verbatimLatitude"]=Coordinate
            elif "E" in Coordinate.upper(): 
                self.data.loc[index,"verbatimLongitude"]=Coordinate
            elif "W" or "O" in Coordinate.upper(): 
                self.data.loc[index,"verbatimLongitude"]=Coordinate

    
    def verbatimCoordinates_utm_sep(self,index):
        Coordinate= self.data.loc[index,"verbatimCoordinates"].split(" ")
        for elements in Coordinate:
            if "N" or "S" in elements.upper(): timezone_index=Coordinate.index(elements)
        Coordinate_indexes=list(range(0,len(Coordinate)))
        Coordinate_indexes.remove(timezone_index)
        if int(Coordinate[Coordinate_indexes[0]]) > int(Coordinate[Coordinate_indexes[1]]):
            self.data.loc[index,"verbatimLatitude"]=Coordinate[Coordinate_indexes[1]]
            self.data.loc[index,"verbatimLongitude"]=Coordinate[Coordinate_indexes[0]]
        else:
            self.data.loc[index,"verbatimLatitude"]=Coordinate[0]
            self.data.loc[index,"verbatimLongitude"]=Coordinate[1]
    
    def verb_lat_long_autocomplete(self):
        """
        check existence of verbatimLatitude & verbatimLongitude:
            -Exist: fill verbatimLatitude & verbatimLongitude from verbatimCoordinates data
            -Absence: create and fill verbatimLatitude & verbatimLongitude from verbatimCoordinates data
        """
        if set(['verbatimLatitude', 'verbatimLongitude']).issubset(set(self.data.columns.to_list())) is False:
            verb_coord_position=self.data.columns.to_list().index("verbatimCoordinates")+1
            self.data.insert(verb_coord_position,"verbatimLatitude",np.nan)
            self.data.insert(verb_coord_position+1,"verbatimLongitude",np.nan)
            for index in self.data.index:
                if pd.isna(self.data.loc[index,"verbatimCoordinates"]):
                    pass
                elif isinstance(self.data.loc[index,"verbatimLongitude"],str)==False and isinstance(self.data.loc[index,"verbatimLatitude"],str)==False:  #cambio
                    if (pd.isna(self.data.loc[index,"verbatimLongitude"])) or (pd.isna(self.data.loc[index,"verbatimLatitude"])): #cambio
                        if self.data.loc[index,"verbatimCoordinateSystem"]=="UTM":
                            self.verbatimCoordinates_utm_sep()
                        elif self.data.loc[index,"verbatimCoordinateSystem"]=="degrees minutes seconds" or self.data.loc[index,"verbatimCoordinateSystem"]=="degrees decimal minutes":
                                self.verbatimCoordinates_dms_sep()
                        else:
                            pass                    
        if set(['verbatimLatitude', 'verbatimLongitude']).issubset(set(self.data.columns.to_list())) is True:
            for index in self.data.index:
                if pd.isna(self.data.loc[index,"verbatimCoordinates"]):
                    pass
                elif isinstance(self.data.loc[index,"verbatimLongitude"],str)==False and isinstance(self.data.loc[index,"verbatimLatitude"],str)==False:  #cambio
                    if (pd.isna(self.data.loc[index,"verbatimLongitude"])) or (pd.isna(self.data.loc[index,"verbatimLatitude"])): #cambio
                        if self.data.loc[index,"verbatimCoordinateSystem"]=="UTM":
                            self.verbatimCoordinates_utm_sep(index)
                        elif self.data.loc[index,"verbatimCoordinateSystem"]=="degrees minutes seconds" or self.data.loc[index,"verbatimCoordinateSystem"]=="degrees decimal minutes":
                            self.verbatimCoordinates_dms_sep(index)
                        else:
                            pass
                     
    def verbatimCoordinates_autocomplete(self):
        """
        Check the existence of verbatimCoordinates:
            - Exist: check if verbatimLatitude & verbatimLongitude exist and then fill verbatimCoordinates
            - Absence: create verbatimCoordinates then check if verbatimLatitude & verbatimLongitude exist and then fill verbatimCoordinates
        """
        if "verbatimCoordinates" not in self.data.columns:
            if "verbatimLatitude" and "verbatimLongitude" in self.data.columns:
                self.data["verbatimCoordinates"]=np.nan
                for index in self.data.index:
                    if (pd.isna(self.data.loc[index,"verbatimLatitude"]),pd.isna(self.data.loc[index,"verbatimLongitude"])) == (False,False) :
                        lat,lon=self.data.loc[index,"verbatimLatitude"],self.data.loc[index,"verbatimLongitude"]
                        self.data.loc[index,"verbatimCoordinates"]=f"{lat}, {lon}"
                    else :pass 
        if "verbatimCoordinates" in self.data.columns:
            for index in self.data.index:
                if pd.isna(self.data.loc[index,"verbatimCoordinates"]):
                    if (pd.isna(self.data.loc[index,"verbatimLatitude"]),pd.isna(self.data.loc[index,"verbatimLongitude"])) == (False,False):
                        lat,lon=self.data.loc[index,"verbatimLatitude"],self.data.loc[index,"verbatimLongitude"]
                        self.data.loc[index,"verbatimCoordinates"]=f"{lat}, {lon}"
                    else: pass
                      
    def verbatimCoordinateSystem_autocomplete(self): #work in progress
        """
        fill verbatimCoordinateSystem field based on verbatimCoordinates data
        """
        minutes="'"
        seconds='"'
        for index in self.data.index:
            if pd.isna(self.data.loc[index,"verbatimCoordinates"]) is False:
                try:
                    if "°" or "d" in self.data.loc[index,"verbatimCoordinates"]: 
                        if minutes and seconds in self.data.loc[index,"verbatimCoordinates"]: 
                            self.data.loc[index,"verbatimCoordinateSystem"]="degrees minutes seconds"
                        elif minutes in self.data.loc[index,"verbatimCoordinates"]: 
                            self.data.loc[index,"verbatimCoordinateSystem"]="degrees decimal minutes"
                    elif "." in self.data.loc[index,"verbatimCoordinates"]: 
                        self.data.loc[index,"verbatimCoordinateSystem"]="decimal degrees"
                    else: 
                        self.data.loc[index,"verbatimCoordinateSystem"]="UTM"
                except: pass
    
    def coordinatePrecision_autocomplete(self):
        """
        fill coordinatePrecision based on verbatimLatitude & verbatimLongitude (preference) else decimalLatitude & decimalLongitude information
        """
        for index in self.data.index:
            if (self.data.loc[index,"verbatimLatitude"] or self.data.loc[index,"verbatiLongitude"]) is np.nan or self.data.loc[index,"verbatimCoordinateSystem"]=="decimal degrees":
                if (self.data.loc[index,"decimalLatitude"] or self.data.loc[index,"decimalLongitude"]) is not np.nan:
                    try:
                        lat=self.data.loc[index,"decimalLatitude"].split(".")
                        lon=self.data.loc[index,"decimalLongitude"].split(".")
                        self.data.loc[index,"coordinatePrecision"]="0."+"0"*(min(len(lat[1]),len(lon[1]))-1)+"1"
                    except: pass
            elif self.data.loc[index,"verbatimCoordinateSystem"]=="degrees minutes seconds":
                try:
                    lat=self.data.loc[index,"verbatimLatitude"]
                    lon=self.data.loc[index,"verbatimLongitude"]
                    srch="'(.+?)\""
                    m_lat=re.search(srch, lat)
                    m_lon=re.search(srch, lon)
                    found_lat=m_lat.group(1)
                    found_lon=m_lon.group(1)
                    if "." in found_lat: 
                        pres=1/pow(10,len(found_lat.split(".")[1]))
                        coordP_lat=pres/3600.
                    else: coordP_lat=1/3600.
                    if "." in found_lon:
                        pres=1/pow(10,len(found_lon.split(".")[1]))
                        coordP_lon=pres/3600.
                    else: coordP_lon=1/3600.
                    self.data.loc[index,"coordinatePrecision"]='{:.7f}'.format(min(coordP_lon,coordP_lat))
                except: pass
            elif self.data.loc[index,"verbatimCoordinateSystem"]=="degrees decimal minutes":
                try:
                    lat=self.data.loc[index,"verbatimLatitude"]
                    lon=self.data.loc[index,"verbatimLongitude"]
                    srch="°(.+?)\'"
                    m_lat=re.search(srch, lat)
                    m_lon=re.search(srch, lon)
                    found_lat=m_lat.group(1)
                    found_lon=m_lon.group(1)
                    if "." in found_lat: 
                        pres=1/pow(10,len(found_lat.split(".")[1]))
                        coordP_lat=pres/60.
                    else: coordP_lat=1/60.
                    if "." in found_lon:
                        pres=1/pow(10,len(found_lon.split(".")[1]))
                        coordP_lon=pres/60.
                    else: coordP_lon=1/60.
                    self.data.loc[index,"coordinatePrecision"]='{:.7f}'.format(min(coordP_lon,coordP_lat))
                except: pass
            else: 
                try:
                    lat=self.data.loc[index,"decimalLatitude"].split(".")
                    lon=self.data.loc[index,"decimalLongitude"].split(".")
                    self.data.loc[index,"coordinatePrecision"]="0."+"0"*(min(len(lat[1]),len(lon[1]))-1)+"1"
                except: pass

# %%
class coord_transform:
    def __init__(self,data):
        self.data=data
    
    def utm_to_dg(self):
        for index in self.data.index:
            if self.data.loc[index,"verbatimCoordinates"] is not np.nan and self.data.loc[index,"verbatimCoordinateSystem"]=="UTM":
                coordinate= self.data.loc[index,"verbatimCoordinates"].split(" ")
                for elements in coordinate:
                    if "N" in elements.upper(): 
                        zone_index=coordinate.index(elements)
                        Global="North"
                    elif "S" in elements.upper():
                        zone_index=coordinate.index(elements)
                        Global="South"
                if Global=="South":
                    lat,lon=utm.to_latlon(self.data.loc[index,"verbatimLatitude"], self.data.loc[index,"verbatimLongitude"], int(coordinate[zone_index].upper().replace("S","")), northern=False)
                elif Global=="North":
                    lat,lon=utm.to_latlon(self.data.loc[index,"verbatimLatitude"], self.data.loc[index,"verbatimLongitude"], int(coordinate[zone_index].upper().replace("N","")), northern=True)
                self.data.loc[index,"decimalLatitude"]="{0:.7f}".format(lat)
                self.data.loc[index,"decimalLongitude"]="{0:.7f}".format(lon)
                #self.data.loc[index,"georeferenceSources"]="GeoParser Marcelo Oyaneder"
    
    def dms_to_dg(self):
        """
        fill decimalLatitude & decimalLongitude based on verbatimLatitude & verbatimLongitude transformation
        fill geodeticDatum based on verbatimSRS info
        """
        for index in self.data.index:
            if (self.data.loc[index,"verbatimCoordinateSystem"]=="degrees minutes seconds" or self.data.loc[index,"verbatimCoordinateSystem"]=="degrees decimal minutes") and pd.isna(self.data.loc[index,"verbatimCoordinates"]) is False:
                try: 
                    location= self.data.loc[index,"verbatimCoordinates"]
                    if "O" in location.upper():
                        location=location.replace("O","W")
                    response=requests.get(f"http://data.canadensys.net/tools/coordinates.json?data=35|{location}&idprovided=TRUE").json()
                    lon,lat=response["features"][0]["geometry"]["coordinates"]
                    self.data.loc[index,"decimalLatitude"]="{0:.7f}".format(lat)
                    self.data.loc[index,"decimalLongitude"]="{0:.7f}".format(lon)
                except:
                    self.data.loc[index,"decimalLatitude"]="Error"
                    self.data.loc[index,"decimalLongitude"]="Error"
    
    def geodeticDatum_autocomplete(self): 
        """
        fill geodeticDatum based on info from verbatimSRS 
        if decimalLatitude or decimalLongitude doesnt exist value is na 
        """
        for index in self.data.index:
            if (pd.isna(data.loc[index,"decimalLatitude"]) is False) and (pd.isna(data.loc[index,"decimalLongitude"]) is False):
                if pd.isna(data.loc[index,"geodeticDatum"]):
                    if pd.isna(data.loc[index,"verbatimSRS"]):
                        data.loc[index,"geodeticDatum"]="unknown"
                    else:
                        data.loc[index,"geodeticDatum"]=data.loc[index,"verbatimSRS"]
                else: pass
    
    def continent_autocomplete(self):
        """
        fill continent based on country data
        """
        country_data=pd.read_csv("https://raw.githubusercontent.com/VertNet/DwCVocabs/master/vocabs/countryCode_country_continent_merged.csv")
        country_data.set_index("country",inplace=True)
        country_data_dict=country_data.to_dict()
        if set(['country']).issubset(set(self.data.columns.to_list())) is True:
            if set(['continent']).issubset(set(self.data.columns.to_list())) is True:
                for index in self.data.index:
                    if self.data.loc[index,"country"] in country_data_dict["continent"].keys() and pd.isna(self.data.loc[index,"continent"]):
                        self.data.loc[index,"continent"]=country_data_dict["continent"][self.data.loc[index,"country"]]
                    else: pass        
            elif set(['continent']).issubset(set(self.data.columns.to_list())) is False:
                self.data.insert(self.data.columns.to_list().index("country")-1,"continent",np.nan) #en que lugar lo coloco
                for index in self.data.index:
                    if self.data.loc[index,"country"] in country_data_dict["continent"].keys():
                        self.data.loc[index,"continent"]=country_data_dict["continent"][self.data.loc[index,"country"]]
                    else: pass  
        else: pass 
    
    def location_autocomplete(self): #include country, country_code, stateProvince, county, municipality 
        """
        fill country, countryCode, stateProvince, county, municipality based on lat,lon info using gbif API 
        lacking develop about marine regions         
        """
        for index in self.data.index:
            try:
                lat=self.data.loc[index,"decimalLatitude"]
                lon=self.data.loc[index,"decimalLongitude"]
                result=requests.get(f"https://api.gbif-uat.org/v1/geocode/reverse?lat={lat}&lng={lon}").json()
                for elements in result:
                    if elements["source"]=="http://gadm.org/":
                        if elements["type"]=="GADM0":
                            self.data.loc[index,"country"]=elements["title"]
                            self.data.loc[index,"countryCode"]=elements["isoCountryCode2Digit"]
                        elif elements["type"]=="GADM1": self.data.loc[index,"stateProvince"]=elements["title"]
                        elif elements["type"]=="GADM2": self.data.loc[index,"county"]=elements["title"]
                        elif elements["type"]=="GADM3": self.data.loc[index,"municipality"]=elements["title"]
            except: 
                pass
        
    def higherGeography_autocomplete(self): 
        """
        fill higherGeography 
        """
        dwc_labels=["continent","waterBody","country","countryCode","stateProvince","county","municipality","islandGroup","island"]
        dwc_labels_selected=[i for i in dwc_labels if i in self.data.columns]
        try:
            for index in self.data.index:
                higherGeography_list=[]
                if pd.isna(self.data.loc[index,"higherGeography"]) is True:
                    for elements in dwc_labels_selected:
                        if isinstance(self.data.loc[index,elements], str): higherGeography_list.append(self.data.loc[index,elements])
                higherGeography_str=" | ".join(higherGeography_list)
                if higherGeography_str=="":
                    self.data.loc[index,"higherGeography"]=np.nan
                else:
                    self.data.loc[index,"higherGeography"]=higherGeography_str         
        except KeyError:
            self.data["higherGeography"]=np.nan
            for index in self.data.index:
                higherGeography_list=[]
                if pd.isna(self.data.loc[index,"higherGeography"]) is True:
                    for elements in dwc_labels_selected:
                        if isinstance(self.data.loc[index,elements], str): higherGeography_list.append(self.data.loc[index,elements])
                higherGeography_str=" | ".join(higherGeography_list)
                if higherGeography_str == "":
                    self.data.loc[index,"higherGeography"]=np.nan
                else:
                    self.data.loc[index,"higherGeography"]=higherGeography_str

# %% [markdown]
# # TESTING...

# %%
import pandas as pd
data=pd.read_csv("new_georref.csv")

data
# Out:
#                                                                                           higherGeography  \
# 0                                                                                                     NaN
# 1                                                                                                     NaN
# 2                                                                                                     NaN
# 3                                                                                                     NaN
# 4                                                                                                     NaN
# 5                                                                                                     NaN
# 6                                                                                                     NaN
# 7                                                                                                     NaN
# 8                                                                                                     NaN
# 9                                                                                                     NaN
# 10                                                                                                    NaN
# 11                                                                                                    NaN
# 12                                                                                                    NaN
# 13                                                                                                    NaN
# 14                                                                                                    NaN
# 15                                                                                                    NaN
# 16                                                                                                    NaN
# 17                                                                                                    NaN
# 18                                                                                                    NaN
# 19                                                                                                    NaN
# 20                                                                                                    NaN
# 21                                                                                                    NaN
# 22   América | Sudamérica | Chile | Región de La Araucanía | Malleco | Purén | Monumento Natural Contulmo
# 23                                                                                                    NaN
# 24                             América | Sudamérica | Chile | Región de La Araucanía | Malleco | Traiguén
# 25                                                                                                    NaN
# 26            América | Sudamérica | Chile | Región de La Araucanía | Cautín | Padre Las Casas | Truftruf
# 27                                                                                                    NaN
# 28                                                                                                    NaN
# 29                                                                                                    NaN
# 30                                                                                                    NaN
# 31                                                                                                    NaN
# 32                                                                                                    NaN
# 33                                                                                                    NaN
# 34                                                                                                    NaN
# 35                                                                                                    NaN
# 36                                                                                                    NaN
# 37                                                                                                    NaN
# 38                                                                                                    NaN
# 39                                                                                                    NaN
# 40                                                                                                    NaN
# 41                                                                                                    NaN
# 42                                                                                                    NaN
# 43                                                                                                    NaN
# 44                                                                                                    NaN
# 45                                                                                                    NaN
# 46         América | Sudamérica | Chile | Región de Los Lagos | Llanquihue | Puerto Varas | Volcán Osorno
# 47                                                                                                    NaN
# 48                                                                                                    NaN
# 49                                                                                                    NaN
# 50                                                                                                    NaN
# 51                                                                                                    NaN
# 52                                                                                                    NaN
# 53                                                                                                    NaN
# 54                                                                                                    NaN
# 55                                                                                                    NaN
# 56                                                                                                    NaN
# 57                                                                                                    NaN
# 58                                                                                                    NaN
# 59                                                                                                    NaN
# 60                                                                                                    NaN
# 61                                                                                                    NaN
# 62                              América | Sudamérica | Chile | Región de Los Lagos | Llanquihue | Calbuco
# 63                                                                                                    NaN
# 64                                                                                                    NaN
# 65                                                                                                    NaN
# 66                                                                                                    NaN
# 67                                                                                                    NaN
# 68                                                                                                    NaN
# 69                                                                                                    NaN
# 70                                                                                                    NaN
# 71                                                                                                    NaN
# 72                                                                                                    NaN
# 73                                                                                                    NaN
# 74                                                                                                    NaN
# 75                                                                                                    NaN
# 76                                                                                                    NaN
# 77                                                                                                    NaN
# 78                                                                                                    NaN
# 79                                                                                                    NaN
# 80                         América | Sudamérica | Chile | Región de Los Lagos | Llanquihue | Puerto Montt
# 81                                                                                                    NaN
# 82                                                                                                    NaN
# 83                                                                                                    NaN
# 84                                                                                                    NaN
# 85                                                                                                    NaN
# 86                                                                                                    NaN
# 87                                  América | Sudamérica | Chile | Región de Los Ríos | Valdivia | Corral
# 88                                                                                                    NaN
# 89                                                                                                    NaN
# 90                                                                                                    NaN
# 91                                                                                                    NaN
# 92                                                                                                    NaN
# 93                                                                                                    NaN
# 94                                                                                                    NaN
# 95                            América | Sudamérica | Chile | Región de Valparaíso | Valparaíso | Quintero
# 96                                                                                                    NaN
# 97                                                                                                    NaN
# 98                                                                                                    NaN
# 99            América | Sudamérica | Chile | Región de Valparaíso | Los Andes | Calle Larga | La Placilla
# 100                                                                                                   NaN
# 101                                                                                                   NaN
# 102                                                                                                   NaN
# 103                                                                                                   NaN
# 104                                                                                                   NaN
# 105                                                                                                   NaN
# 106           América | Sudamérica | Chile | Región de Valparaíso | Valparaíso | Valparaíso | Playa Ancha
# 107                                                                                                   NaN
# 108                                                                                                   NaN
# 109              América | Sudamérica | Chile | Región de Valparaíso | Los Andes | Los Andes | Río Blanco
#
#                        waterBody  continent  country  countryCode  \
# 0                            NaN        NaN      NaN          NaN
# 1                            NaN        NaN      NaN          NaN
# 2    South-Eastern Pacific Ocean        NaN      NaN          NaN
# 3    South-Eastern Pacific Ocean        NaN      NaN          NaN
# 4                            NaN        NaN      NaN          NaN
# 5    South-Eastern Pacific Ocean        NaN      NaN          NaN
# 6                            NaN        NaN      NaN          NaN
# 7                            NaN        NaN      NaN          NaN
# 8                            NaN        NaN      NaN          NaN
# 9                            NaN        NaN      NaN          NaN
# 10                           NaN        NaN      NaN          NaN
# 11                           NaN        NaN      NaN          NaN
# 12   South-Eastern Pacific Ocean        NaN      NaN          NaN
# 13                           NaN        NaN      NaN          NaN
# 14                           NaN        NaN      NaN          NaN
# 15                           NaN        NaN      NaN          NaN
# 16                           NaN        NaN      NaN          NaN
# 17                           NaN        NaN      NaN          NaN
# 18                           NaN        NaN      NaN          NaN
# 19   South-Eastern Pacific Ocean        NaN      NaN          NaN
# 20   South-Eastern Pacific Ocean        NaN      NaN          NaN
# 21                           NaN        NaN      NaN          NaN
# 22                           NaN        NaN      NaN          NaN
# 23                           NaN        NaN      NaN          NaN
# 24                           NaN        NaN      NaN          NaN
# 25                           NaN        NaN      NaN          NaN
# 26                           NaN        NaN      NaN          NaN
# 27                           NaN        NaN      NaN          NaN
# 28                           NaN        NaN      NaN          NaN
# 29                           NaN        NaN      NaN          NaN
# 30                           NaN        NaN      NaN          NaN
# 31                           NaN        NaN      NaN          NaN
# 32                           NaN        NaN      NaN          NaN
# 33                           NaN        NaN      NaN          NaN
# 34                           NaN        NaN      NaN          NaN
# 35                           NaN        NaN      NaN          NaN
# 36                           NaN        NaN      NaN          NaN
# 37                           NaN        NaN      NaN          NaN
# 38                           NaN        NaN      NaN          NaN
# 39                           NaN        NaN      NaN          NaN
# 40                           NaN        NaN      NaN          NaN
# 41                           NaN        NaN      NaN          NaN
# 42                           NaN        NaN      NaN          NaN
# 43                           NaN        NaN      NaN          NaN
# 44                           NaN        NaN      NaN          NaN
# 45                           NaN        NaN      NaN          NaN
# 46                           NaN        NaN      NaN          NaN
# 47                           NaN        NaN      NaN          NaN
# 48                           NaN        NaN      NaN          NaN
# 49   South-Eastern Pacific Ocean        NaN      NaN          NaN
# 50                           NaN        NaN      NaN          NaN
# 51               Océano Pacífico        NaN      NaN          NaN
# 52                           NaN        NaN      NaN          NaN
# 53   South-Eastern Pacific Ocean        NaN      NaN          NaN
#
# 82             NaN     NaN           NaN          NaN     NaN
# 83             NaN     NaN           NaN          NaN     NaN
# 84             NaN     NaN           NaN          NaN     NaN
# 85             NaN     NaN           NaN          NaN     NaN
# 86             NaN     NaN           NaN          NaN     NaN
# 87             NaN     NaN           NaN          NaN     NaN
# 88             NaN     NaN           NaN          NaN     NaN
# 89             NaN     NaN           NaN          NaN     NaN
# 90             NaN     NaN           NaN          NaN     NaN
# 91             NaN     NaN           NaN          NaN     NaN
# 92             NaN     NaN           NaN          NaN     NaN
# 93             NaN     NaN           NaN          NaN     NaN
# 94             NaN     NaN           NaN          NaN     NaN
# 95             NaN     NaN           NaN          NaN     NaN
# 96             NaN     NaN           NaN          NaN     NaN
# 97             NaN     NaN           NaN          NaN     NaN
# 98             NaN     NaN           NaN          NaN     NaN
# 99             NaN     NaN           NaN          NaN     NaN
# 100            NaN     NaN           NaN          NaN     NaN
# 101            NaN     NaN           NaN          NaN     NaN
# 102            NaN     NaN           NaN          NaN     NaN
# 103            NaN     NaN           NaN          NaN     NaN
# 104            NaN     NaN           NaN          NaN     NaN
# 105            NaN     NaN           NaN          NaN     NaN
# 106            NaN     NaN           NaN          NaN     NaN
# 107            NaN     NaN           NaN          NaN     NaN
# 108            NaN     NaN           NaN          NaN     NaN
# 109            NaN     NaN           NaN          NaN     NaN
#
#                                                                 locality  \
# 0                        Lagunita en Ruta 181, 6 km al Este de Lonquimay
# 1                                                          R.F. Niblinto
# 2                                                                Carahue
# 3                                                                Carahue
# 4                                                          P.N. Tolhuaca
# 5                                                                Carahue
# 6                                                               La Fusta
# 7                                                               Niblinto
# 8                                                   PN Tolhuaca, sendero
# 9                                            Lago Budi - Romopulli Huapi
# 10                                                        Laguna Malleco
# 11                            Reserva Forestal Niblinto, Sector Niblinto
# 12                                                               Carahue
# 13                                                            Curacautin
# 14                                                            Nahuelbuta
# 15                                               Lago Galletué, Quilquén
# 16                                                Lago Budi - Deume Este
# 17                          Parque Nacional Conguillío - Laguna Arcoiris
# 18                                                         Cautin: Cunco
# 19                                                               Carahue
# 20                                                               Carahue
# 21                                               Cautin: Padre Las Casas
# 22                                            Monumento Natural Contulmo
# 23                                                              Contulmo
# 24                                                                   NaN
# 25        Parque Nacional Tolhuaca, en cerros al norte de Laguna Malleco
# 26                                                              Truftruf
# 27                                                             Lonquimay
# 28                                                    Cautin: Trailanqui
# 29                                           Malleco: Termas De Tolhuaca
# 30                                                           Las Lomitas
# 31                                                           Huasco Bajo
# 32                                  South Of Chañaral, South Of Barquito
# 33                                                       S. Puerto Viejo
# 34        Entry To Pan De Azucar Parque Nacional From Ruta 5 Norte 276 M
# 35                                                   Morro Copiapo; 275M
# 36                          Iii Region, P.N.Pan De Azucar, Qda. Castillo
# 37                                                      Cerro Algarrobal
# 38                                                   Lomitas, Mirador, ?
# 39                                                           Huasco Bajo
# 40                                                        Playa de Cucao
# 41                                                        Playa de Cucao
# 42                                     Río Frío, Tramo Yelcho a La Junta
# 43                                                             Frutillar
# 44                                                               Pelluco
# 45                                                                Pargua
# 46                                                         Volcán Osorno
# 47                                                        Camino a Chepu
# 48                                                                 Ancud
# 49                                                               Calbuco
# 50           Lago Llanquihue - bahía norte Totoral, hay una piscicultura
# 51                                                           Canal Lemuy
# 52                                                      Cerros de Huelde
# 53                                    Fiordo Comau, Huinay, Punta Gruesa
# 54                                            alrededores de Alto Palena
# 55                                             Cipresal Norte de Chaitén
# 56                                                        Canal Dalcahue
# 57                                                        Camino Calbuco
# 58                                              Puerto Montt - costanera
# 59                                                            Huellelhue
# 60                                                        Frutillar bajo
# 61                                            Chaiten, cipresal al Norte
# 62                                                                   NaN
# 63                                                                Chacao
# 64                                                        Cerca de Ancud
# 65                                                          Canal Laitec
# 66                                                       Canal San Pedro
# 67                       Llanquihue: Parque V Perez Rosales, Punta Guano
# 68                                                             Pichicolo
# 69                                                    Bahía Puerto Montt
# 70                                                              Ensenada
# 71                                                       Camino a Ñapeco
# 72                                              Camino a Puerto Cardenas
# 73                                                       Puerto Cardenas
# 74                                                            B. Chaiten
# 75                                                                Osorno
# 76                                                                Chilo‚
# 77                                                Alto Palena. El Malito
# 78   Parque Nacional Vicente Peréz Rosales, Sendero Las Chauras, Cayutué
# 79                                                              Cahuelmó
# 80                                                                   NaN
# 81                                                       Frutillar. CEFF
# 82                                               Parque Nacional Puyehue
# 83                                                            Tepuhueico
# 84                                                              Valdivia
# 85                                                       Mallin de Amaro
# 86                                                            Llancacura
# 87                                                                   NaN
# 88                                                              Valdivia
# 89                                     Lago Panguipulli - sector poblado
# 90                                                   Pendiente de Yunque
# 91                                                        PN. La Campana
# 92                                                                   NaN
# 93                                                             Cartagena
# 94                                                       Laguna El Peral
# 95                                                                   NaN
# 96                                                       Quintay-Tunquén
# 97                                         Estero San Jeronimo. Humedal.
# 98                                                        Isla de Pascua
# 99                                                           La Placilla
# 100                                          Masafuera, Quebrada Sanchez
# 101                                                 Isla Robinson Crusoe
# 102                                                      Limache, Parque
# 103                                              Las Salinas, Las Cruces
# 104                                                 Sector Yali - Camino
# 105              Ocoa, Parque Nacional La Campana, ingreso sector casino
# 106                                                          Playa Ancha
# 107                                    Masatierra, Qda Piedra Agujereada
# 108                                                            El Quisco
# 109                                                           Río Blanco
#
#                                                    verbatimLocality  \
# 0                                                               NaN
# 1                                                     R.F. Niblinto
# 2                                                               NaN
# 3                                                               NaN
# 4                                                     P.N. Tolhuaca
# 5                                                               NaN
# 6                                                          La Fusta
# 7                                                          Niblinto
# 8                                                               NaN
# 9                                                               NaN
# 10                                                              NaN
# 11                                   R. F. Malleco, sector Niblinto
# 12                                                              NaN
# 13                                                       Curacautin
# 14                                                       Nahuelbuta
# 15                                          Lago Galletué, Quilquén
# 16                                                              NaN
# 17                                                              NaN
# 18                                                    Cautin: Cunco
# 19                                                              NaN
# 20                                                              NaN
# 21                                          Cautin: Padre Las Casas
# 22                                                Malleco, Contulmo
# 23                                                         Contulmo
# 24                                                Malleco, Traiguen
# 25                                                    P.N. Tolhuaca
# 26                                                Cautín, Truf Truf
# 27                                                        Lonquimay
# 28                                               Cautin: Trailanqui
# 29                                      Malleco: Termas De Tolhuaca
# 30                                                      Las Lomitas
# 31                                                              NaN
# 32                             South Of Chañaral, South Of Barquito
# 33                                                  S. Puerto Viejo
# 34   Entry To Pan De Azucar Parque Nacional From Ruta 5 Norte 276 M
# 35                                              Morro Copiapo; 275M
# 36                     Iii Region, P.N.Pan De Azucar, Qda. Castillo
# 37                                                 Cerro Algarrobal
# 38                                              Lomitas, Mirador, ?
# 39                                                              NaN
# 40                                                              NaN
# 41                                                              NaN
# 42                                                              NaN
# 43                                                        Frutillar
# 44                                                              NaN
# 45                                                              NaN
# 46                                        Llanquihue, Volcán Osorno
# 47                                                   Camino a Chepu
# 48                                                            Ancud
# 49                                                              NaN
# 50                                                              NaN
# 51                                                              NaN
# 52                                                 Cerros de Huelde
# 53                                                              NaN
# 54                                       alrededores de Alto Palena
# 55                                        Cipresal Norte de Chaitén
# 56                                                              NaN
# 57                                                   Camino Calbuco
# 58                                                              NaN
# 59                                                       Huellelhue
# 60                                                   Frutillar bajo
# 61                                       Chaiten, cipresal al Norte
# 62                                              Llanquihue, Calbuco
# 63                                                              NaN
# 64                                                   Cerca de Ancud
# 65                                                              NaN
# 66                                                              NaN
# 67                  Llanquihue: Parque V Perez Rosales, Punta Guano
# 68                                                        Pichicolo
# 69                                                              NaN
# 70                                                         Ensenada
# 71                                                  Camino a Ñapeco
# 72                                         Camino a Puerto Cardenas
# 73                                                  Puerto Cardenas
# 74                                                              NaN
# 75                                                           Osorno
# 76                                                              NaN
# 77                                           Alto Palena. El Malito
# 78                                       P.N. Vicente Pérez Rosales
# 79                                                              NaN
# 80                                                     Puerto Montt
# 81                                                  Frutillar. CEFF
# 82                                                    P. N. Puyehue
# 83                                                       Tepuhueico
# 84                                                         Valdivia
# 85                                                  Mallin de Amaro
# 86                                                       Llancacura
# 87                                                 Valdivia, Corral
# 88                                                              NaN
# 89                                                              NaN
# 90                                  Juan Fernández, Robinson Crusoe
# 91                                                   PN. La Campana
# 92                                                              NaN
# 93                                                        Cartagena
# 94                                                              NaN
# 95                              Valparaíso, Quintero, Los Arrayanes
# 96                                                              NaN
# 97                                    Estero San Jeronimo. Humedal.
# 98                                                              NaN
# 99                                          Valparaíso, La Placilla
# 100                                     Masafuera, Quebrada Sanchez
# 101                                                             NaN
# 102                                                 Limache, Parque
# 103                                                             NaN
# 104                                                             NaN
# 105                                                             NaN
# 106                                         Valparaíso, Playa Ancha
# 107                               Masatierra, Qda Piedra Agujereada
# 108                                                             NaN
# 109                                           Aconcagua, Río Blanco
#
#      minimumElevationInMeters  maximumElevationInMeters verbatimElevation  \
# 0                         NaN                       NaN               NaN
# 1                         NaN                       NaN               NaN
# 2                         0.0                       0.0               NaN
# 3                         0.0                       0.0               NaN
# 4                         NaN                       NaN               NaN
# 5                         0.0                       0.0               NaN
# 6                         NaN                       NaN               NaN
# 7                         NaN                       NaN               NaN
# 8                         NaN                       NaN               NaN
# 9                         NaN                       NaN               NaN
# 10                        NaN                       NaN               NaN
# 11                        NaN                       NaN               NaN
# 12                        0.0                       0.0               NaN
# 13                        NaN                       NaN               NaN
# 14                        NaN                       NaN               NaN
# 15                        NaN                       NaN               NaN
# 16                        NaN                       NaN               NaN
# 17                        NaN                       NaN               NaN
# 18                        NaN                       NaN               s/i
# 19                        0.0                       0.0               NaN
# 20                        0.0                       0.0               NaN
# 21                        NaN                       NaN               s/i
# 22                        NaN                       NaN               NaN
# 23                        NaN                       NaN               NaN
# 24                        NaN                       NaN               NaN
# 25                        NaN                       NaN               NaN
# 26                        NaN                       NaN               NaN
# 27                        NaN                       NaN              1600
# 28                        NaN                       NaN               s/i
# 29                        NaN                       NaN               s/i
# 30                        NaN                       NaN               NaN
# 31                        NaN                       NaN               NaN
# 32                        NaN                       NaN               NaN
# 33                        NaN                       NaN               NaN
# 34                        NaN                       NaN               s/i
# 35                        NaN                       NaN               NaN
# 36                        NaN                       NaN               NaN
# 37                        NaN                       NaN               NaN
# 38                        NaN                       NaN               NaN
# 39                        NaN                       NaN               NaN
# 40                        NaN                       NaN               NaN
# 41                        NaN                       NaN               NaN
# 42                        NaN                       NaN               NaN
# 43                        NaN                       NaN               NaN
# 44                        NaN                       NaN               NaN
# 45                        NaN                       NaN               NaN
# 46                        NaN                       NaN               NaN
# 47                        NaN                       NaN               NaN
# 48                        NaN                       NaN               NaN
# 49                        0.0                       0.0               NaN
# 50                        NaN                       NaN               NaN
# 51                        NaN                       NaN               NaN
# 52                        NaN                       NaN               NaN
# 53                        0.0                       0.0               NaN
# 54                        NaN                       NaN               NaN
# 55                        NaN                       NaN               NaN
# 56                        NaN                       NaN               NaN
# 57                        NaN                       NaN               NaN
# 58                        NaN                       NaN               NaN
# 59                        NaN                       NaN               NaN
# ...
# 34                                                                                                          En base a la localidad
# 35                                                                                                          En base a la localidad
# 36                                                                                                          En base a la localidad
# 37                                            Localidad Georreferenciada con Directorios de localidades. Impresición del especimén
# 38                                                                                                          En base a la localidad
# 39                                                                                                                             NaN
# 40                                                                                                                             NaN
# 41                                                                                                                             NaN
# 42                                                                                                                             NaN
# 43                                                                                                                             NaN
# 44                                                                                                                             NaN
# 45                                                                                                                             NaN
# 46   Georreferenciado a través de GeoNames, Geolocate,DICES y Google Earth a nivel más detallado indicado en campo higherGeography
# 47                                                                                                                             NaN
# 48                                                                                                                             NaN
# 49                                                                                                                             NaN
# 50                                                                                                                             NaN
# 51                                                                                                                             NaN
# 52                                                                                                                             NaN
# 53                                                                                                                             NaN
# 54                                                                                                                             NaN
# 55                                                                                                                             NaN
# 56                                                                                                                             NaN
# 57                                                                                                                             NaN
# 58                                                                                                                             NaN
# 59                                                                                                                             NaN
# 60                                                                                                                             NaN
# 61                                                                                                                             NaN
# 62   Georreferenciado a través de GeoNames, Geolocate,DICES y Google Earth a nivel más detallado indicado en campo higherGeography
# 63                                                                                                                             NaN
# 64                                                                                                                             NaN
# 65                                                                                                                             NaN
# 66                                                                                                                             NaN
# 67                                                                                                          En base a la localidad
# 68                                                                                                                             NaN
# 69                                                                                                                             NaN
# 70                                                                                                                             NaN
# 71                                                                                                                             NaN
# 72                                                                                                                             NaN
# 73                                                                                                                             NaN
# 74                                                                                                                             NaN
# 75                                                                                                                             NaN
# 76                                                                                                                             NaN
# 77                                                                                                                             NaN
# 78                                                                                                                             NaN
# 79                                                                                                                             NaN
# 80   Georreferenciado a través de GeoNames, Geolocate,DICES y Google Earth a nivel más detallado indicado en campo higherGeography
# 81                                                                                                                             NaN
# 82                                                                                                                             NaN
# 83                                                                                                                             NaN
# 84                                                                                                                             NaN
# 85                                                                                                                             NaN
# 86                                            Localidad Georreferenciada con Directorios de localidades. Impresición del especimén
# 87   Georreferenciado a través de GeoNames, Geolocate,DICES y Google Earth a nivel más detallado indicado en campo higherGeography
#
# 94   4eEDc0BC/RD2KMddqR/tZEaBxbe9xL+WbWwLst9Y4Xo=
# 95   D04k27DfNh8NueOkh0ImHutY0gXMsguq6CsFxFDvI/Y=
# 96   fLC6XA+RzqAqzb8EibMx38XTaslEU32ltdsq38dMmGs=
# 97   3q7RzEIet+YH+EX4QsdTSl5r+2mV5VyNpgVzIaFwcpo=
# 98   NS72U5FxpkM1Z0H3JKaarNldGGtffWx9gXXTqzcDL98=
# 99   c1N2ULzlrKMfpBPYqJPjXg8ca/7oG1cfQDOGkIrN8zc=
# 100  MyUBTfNzm5z0nwL3PkLxvLqv16cWRzWXXgqY6I4rGs0=
# 101  whqG5foV2xOnnMueskw9Ue9HlzFEZL+b5NLsC65pHVg=
# 102  CrT9pu1BBSZUJaNI6AtcS/sABFprRxTfvahCrrXpCJg=
# 103  WMVGT6x3X8QelVT2vrK8VfHJgRtYzIzqwfotW1gyeKc=
# 104  Dzbd6WTD6UBTBOiNrBe0v9Gv6/43mnduOr2X1PYAZdI=
# 105  rbPp7LlP8R78/VBHQiWfqA51+qeeu62rJ8XODXqBm/c=
# 106  HVoHXv8ifqVeUCAYhiDRTuyKmqixjppKV3bwVx7MAbw=
# 107  YCgWdFqJbtrW1Yv4keFu6Ld+IpjfOChW5WP7u/oYAoM=
# 108  /0h1tIuArvSEx1ktY3JjnXCcHGrefNvWljHHsTqfcAs=
# 109  0pjicG7PG7L8583buCEHxwZEMaMUaysKt+Cjr4B+Edk=

# %%
# %%time
#Testing...

db_prep(data).verbatimCoordinates_autocomplete()
db_prep(data).verbatimCoordinateSystem_autocomplete()
db_prep(data).verb_lat_long_autocomplete()
db_prep(data).coordinatePrecision_autocomplete()
# Out:
# Wall time: 92.9 ms

# %%
data.query("verbatimCoordinates.notna()")
# Out:
#     higherGeography waterBody  continent  country  countryCode  stateProvince  \
# 18              NaN       NaN        NaN      NaN          NaN            NaN
# 21              NaN       NaN        NaN      NaN          NaN            NaN
# 28              NaN       NaN        NaN      NaN          NaN            NaN
# 29              NaN       NaN        NaN      NaN          NaN            NaN
# 34              NaN       NaN        NaN      NaN          NaN            NaN
# 67              NaN       NaN        NaN      NaN          NaN            NaN
# 94              NaN       NaN        NaN      NaN          NaN            NaN
# 100             NaN       NaN        NaN      NaN          NaN            NaN
# 107             NaN       NaN        NaN      NaN          NaN            NaN
#
#      county  municipality  islandGroup  island  \
# 18      NaN           NaN          NaN     NaN
# 21      NaN           NaN          NaN     NaN
# 28      NaN           NaN          NaN     NaN
# 29      NaN           NaN          NaN     NaN
# 34      NaN           NaN          NaN     NaN
# 67      NaN           NaN          NaN     NaN
# 94      NaN           NaN          NaN     NaN
# 100     NaN           NaN          NaN     NaN
# 107     NaN           NaN          NaN     NaN
#
#                                                            locality  \
# 18                                                    Cautin: Cunco
# 21                                          Cautin: Padre Las Casas
# 28                                               Cautin: Trailanqui
# 29                                      Malleco: Termas De Tolhuaca
# 34   Entry To Pan De Azucar Parque Nacional From Ruta 5 Norte 276 M
# 67                  Llanquihue: Parque V Perez Rosales, Punta Guano
# 94                                                  Laguna El Peral
# 100                                     Masafuera, Quebrada Sanchez
# 107                               Masatierra, Qda Piedra Agujereada
#
#                                                    verbatimLocality  \
# 18                                                    Cautin: Cunco
# 21                                          Cautin: Padre Las Casas
# 28                                               Cautin: Trailanqui
# 29                                      Malleco: Termas De Tolhuaca
# 34   Entry To Pan De Azucar Parque Nacional From Ruta 5 Norte 276 M
# 67                  Llanquihue: Parque V Perez Rosales, Punta Guano
# 94                                                              NaN
# 100                                     Masafuera, Quebrada Sanchez
# 107                               Masatierra, Qda Piedra Agujereada
#
#      minimumElevationInMeters  maximumElevationInMeters verbatimElevation  \
# 18                        NaN                       NaN               s/i
# 21                        NaN                       NaN               s/i
# 28                        NaN                       NaN               s/i
# 29                        NaN                       NaN               s/i
# 34                        NaN                       NaN               s/i
# 67                        NaN                       NaN               s/i
# 94                        NaN                       NaN               NaN
# 100                       NaN                       NaN               s/i
# 107                       NaN                       NaN               s/i
#
#      minimumDepthInMeters  maximumDepthInMeters  verbatimDepth  \
# 18                    NaN                   NaN            NaN
# 21                    NaN                   NaN            NaN
# 28                    NaN                   NaN            NaN
# 29                    NaN                   NaN            NaN
# 34                    NaN                   NaN            NaN
# 67                    NaN                   NaN            NaN
# 94                    NaN                   NaN            NaN
# 100                   NaN                   NaN            NaN
# 107                   NaN                   NaN            NaN
#
#     locationRemarks decimalLatitude decimalLongitude geodeticDatum  \
# 18              NaN               .                .           NaN
# 21              NaN               .                .           NaN
# 28              NaN               .                .           NaN
# 29              NaN               .                .           NaN
# 34              NaN               .                .           NaN
# 67              NaN               .                .           NaN
# 94              NaN               .                .           NaN
# 100             NaN               .                .           NaN
# 107             NaN               .                .           NaN
#
#      coordinateUncertaintyInMeters coordinatePrecision  footprintSRS  \
# 18                             NaN           0.0000003           NaN
# 21                             NaN           0.0000003           NaN
# 28                             NaN           0.0000003           NaN
# 29                             NaN           0.0000003           NaN
# 34                             NaN           0.0000003           NaN
# 67                             NaN           0.0000003           NaN
# 94                             NaN                 0.1           NaN
# 100                            NaN           0.0000003           NaN
# 107                            NaN           0.0000003           NaN
#
#      footprintWKT             verbatimCoordinates verbatimLatitude  \
# 18            NaN    38°55'0.000"S, 72°2'0.000" W    38°55'0.000"S
# 21            NaN   38°45'0.000"S, 72°35'0.000" W    38°45'0.000"S
# 28            NaN    39°2'0.000"S, 72°15'0.000" W     39°2'0.000"S
# 29            NaN   38°14'0.000"S, 71°44'0.000" W    38°14'0.000"S
# 34            NaN  26°13'50.696"S, 70°39'2.488" W   26°13'50.696"S
# 67            NaN    41°9'0.000"S, 72°18'0.000" W     41°9'0.000"S
# 94            NaN                  6289700 257800              NaN
# 100           NaN   33°45'0.000"S, 80°46'0.000" W    33°45'0.000"S
# 107           NaN   33°38'0.000"S, 78°51'0.000" W    33°38'0.000"S
#
#     verbatimLongitude verbatimCoordinateSystem  verbatimSRS georeferencedBy  \
# 18      72°2'0.000" W  degrees minutes seconds          NaN      M. Treumun
# 21     72°35'0.000" W  degrees minutes seconds          NaN      M. Treumun
# 28     72°15'0.000" W  degrees minutes seconds          NaN      M. Treumun
# 29     71°44'0.000" W  degrees minutes seconds          NaN      M. Treumun
# 34     70°39'2.488" W  degrees minutes seconds          NaN      M. Treumun
# 67     72°18'0.000" W  degrees minutes seconds          NaN      M. Treumun
# 94                NaN                      NaN          NaN     Charif Tala
# 100    80°46'0.000" W  degrees minutes seconds          NaN      M. Treumun
# 107    78°51'0.000" W  degrees minutes seconds          NaN      M. Treumun
#
#     georeferencedDate  georeferenceProtocol georeferenceSources  \
# 18         2018-09-07                   NaN                 NaN
# 21         2018-09-07                   NaN                 NaN
# 28         2018-09-07                   NaN                 NaN
# 29         2018-09-07                   NaN                 NaN
# 34         2018-09-07                   NaN                 NaN
# 67         2018-09-07                   NaN                 NaN
# 94                NaN                   NaN        Google Earth
# 100        2018-09-07                   NaN                 NaN
# 107        2018-09-07                   NaN                 NaN
#
#      georeferenceVerificationStatus     georeferenceRemarks  \
# 18                              NaN  En base a la localidad
# 21                              NaN  En base a la localidad
# 28                              NaN  En base a la localidad
# 29                              NaN  En base a la localidad
# 34                              NaN  En base a la localidad
# 67                              NaN  En base a la localidad
# 94                              NaN                     NaN
# 100                             NaN  En base a la localidad
# 107                             NaN  En base a la localidad
#
#                                        localityid
# 18   DJK/F1K+y0BrVZJC8WqhXXao9psawnd3vgcIBmDwEkM=
# 21   3y8XajQtDujwAH0aRMXw9TlaiVTjUIFoZ3pKML4qLTY=
# 28   VynSmlTthK9N7jVp8xoEWOQzHgn45zpG2QBAG2dYQC8=
# 29   dj2qw/5FanHksCpVG/Jci5vD3Vsyvld74Dg3xXVb3VQ=
# 34   yDNfsPgjmET2GM8++vd4OK+wJqPKUpvBVsYK/JiLO0k=
# 67   Z+pWP41/ZGyg01I+zJfdZUWmeWLEjQb5RUmocDhAIcs=
# 94   4eEDc0BC/RD2KMddqR/tZEaBxbe9xL+WbWwLst9Y4Xo=
# 100  MyUBTfNzm5z0nwL3PkLxvLqv16cWRzWXXgqY6I4rGs0=
# 107  YCgWdFqJbtrW1Yv4keFu6Ld+IpjfOChW5WP7u/oYAoM=

# %%
# %%time
# Testing ...
#coord_transform(data).utm_to_dg()
coord_transform(data).dms_to_dg()
coord_transform(data).geodeticDatum_autocomplete()  
coord_transform(data).location_autocomplete() 
coord_transform(data).continent_autocomplete() 
coord_transform(data).higherGeography_autocomplete()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# ~\Documents\GitHub\Date_GeoParser\GeoParser\GeoParser.py in geodeticDatum_autocomplete(self)
#    1013         """
#    1014         for index in self.data.index:
# -> 1015             if (pd.isna(self.data.loc[index,"decimalLatitude"]) is False) and (pd.isna(self.data.loc[index,"decimalLongitude"]) is False):
#    1016                 if pd.isna(self.data.loc[index,"geodeticDatum"]):
#    1017                     if pd.isna(self.data.loc[index,"verbatimSRS"]):
#
# NameError: name 'data' is not defined

# %%
data.query("verbatimCoordinates.notna()")
# Out:
#                                                               higherGeography  \
# 18                   South America | Chile | CL | Araucanía | Cautín | Vilcun
# 21           South America | Chile | CL | Araucanía | Cautín | Nueva Imperial
# 28                    South America | Chile | CL | Araucanía | Cautín | Cunco
# 29              South America | Chile | CL | Araucanía | Malleco | Curacautin
# 34                 South America | Chile | CL | Atacama | Chañaral | Chanaral
# 67         South America | Chile | CL | Los Lagos | Llanquihue | Puerto Varas
# 94                                                                        NaN
# 100  South America | Chile | CL | Valparaíso | ísla de Pascua | Ocean Islands
# 107  South America | Chile | CL | Valparaíso | ísla de Pascua | Ocean Islands
#
#     waterBody      continent country countryCode stateProvince  \
# 18        NaN  South America   Chile          CL     Araucanía
# 21        NaN  South America   Chile          CL     Araucanía
# 28        NaN  South America   Chile          CL     Araucanía
# 29        NaN  South America   Chile          CL     Araucanía
# 34        NaN  South America   Chile          CL       Atacama
# 67        NaN  South America   Chile          CL     Los Lagos
# 94        NaN            NaN     NaN         NaN           NaN
# 100       NaN  South America   Chile          CL    Valparaíso
# 107       NaN  South America   Chile          CL    Valparaíso
#
#              county    municipality  islandGroup  island  \
# 18           Cautín          Vilcun          NaN     NaN
# 21           Cautín  Nueva Imperial          NaN     NaN
# 28           Cautín           Cunco          NaN     NaN
# 29          Malleco      Curacautin          NaN     NaN
# 34         Chañaral        Chanaral          NaN     NaN
# 67       Llanquihue    Puerto Varas          NaN     NaN
# 94              NaN             NaN          NaN     NaN
# 100  ísla de Pascua   Ocean Islands          NaN     NaN
# 107  ísla de Pascua   Ocean Islands          NaN     NaN
#
#                                                            locality  \
# 18                                                    Cautin: Cunco
# 21                                          Cautin: Padre Las Casas
# 28                                               Cautin: Trailanqui
# 29                                      Malleco: Termas De Tolhuaca
# 34   Entry To Pan De Azucar Parque Nacional From Ruta 5 Norte 276 M
# 67                  Llanquihue: Parque V Perez Rosales, Punta Guano
# 94                                                  Laguna El Peral
# 100                                     Masafuera, Quebrada Sanchez
# 107                               Masatierra, Qda Piedra Agujereada
#
#                                                    verbatimLocality  \
# 18                                                    Cautin: Cunco
# 21                                          Cautin: Padre Las Casas
# 28                                               Cautin: Trailanqui
# 29                                      Malleco: Termas De Tolhuaca
# 34   Entry To Pan De Azucar Parque Nacional From Ruta 5 Norte 276 M
# 67                  Llanquihue: Parque V Perez Rosales, Punta Guano
# 94                                                              NaN
# 100                                     Masafuera, Quebrada Sanchez
# 107                               Masatierra, Qda Piedra Agujereada
#
#      minimumElevationInMeters  maximumElevationInMeters verbatimElevation  \
# 18                        NaN                       NaN               s/i
# 21                        NaN                       NaN               s/i
# 28                        NaN                       NaN               s/i
# 29                        NaN                       NaN               s/i
# 34                        NaN                       NaN               s/i
# 67                        NaN                       NaN               s/i
# 94                        NaN                       NaN               NaN
# 100                       NaN                       NaN               s/i
# 107                       NaN                       NaN               s/i
#
#      minimumDepthInMeters  maximumDepthInMeters  verbatimDepth  \
# 18                    NaN                   NaN            NaN
# 21                    NaN                   NaN            NaN
# 28                    NaN                   NaN            NaN
# 29                    NaN                   NaN            NaN
# 34                    NaN                   NaN            NaN
# 67                    NaN                   NaN            NaN
# 94                    NaN                   NaN            NaN
# 100                   NaN                   NaN            NaN
# 107                   NaN                   NaN            NaN
#
#     locationRemarks decimalLatitude decimalLongitude geodeticDatum  \
# 18              NaN     -38.9166667      -72.0333333       unknown
# 21              NaN     -38.7500000      -72.5833333       unknown
# 28              NaN     -39.0333333      -72.2500000       unknown
# 29              NaN     -38.2333333      -71.7333333       unknown
# 34              NaN     -26.2307489      -70.6506911       unknown
# 67              NaN     -41.1500000      -72.3000000       unknown
# 94              NaN               .                .       unknown
# 100             NaN     -33.7500000      -80.7666667       unknown
# 107             NaN     -33.6333333      -78.8500000       unknown
#
#      coordinateUncertaintyInMeters coordinatePrecision  footprintSRS  \
# 18                             NaN           0.0000003           NaN
# 21                             NaN           0.0000003           NaN
# 28                             NaN           0.0000003           NaN
# 29                             NaN           0.0000003           NaN
# 34                             NaN           0.0000003           NaN
# 67                             NaN           0.0000003           NaN
# 94                             NaN                 0.1           NaN
# 100                            NaN           0.0000003           NaN
# 107                            NaN           0.0000003           NaN
#
#      footprintWKT             verbatimCoordinates verbatimLatitude  \
# 18            NaN    38°55'0.000"S, 72°2'0.000" W    38°55'0.000"S
# 21            NaN   38°45'0.000"S, 72°35'0.000" W    38°45'0.000"S
# 28            NaN    39°2'0.000"S, 72°15'0.000" W     39°2'0.000"S
# 29            NaN   38°14'0.000"S, 71°44'0.000" W    38°14'0.000"S
# 34            NaN  26°13'50.696"S, 70°39'2.488" W   26°13'50.696"S
# 67            NaN    41°9'0.000"S, 72°18'0.000" W     41°9'0.000"S
# 94            NaN                  6289700 257800              NaN
# 100           NaN   33°45'0.000"S, 80°46'0.000" W    33°45'0.000"S
# 107           NaN   33°38'0.000"S, 78°51'0.000" W    33°38'0.000"S
#
#     verbatimLongitude verbatimCoordinateSystem  verbatimSRS georeferencedBy  \
# 18      72°2'0.000" W  degrees minutes seconds          NaN      M. Treumun
# 21     72°35'0.000" W  degrees minutes seconds          NaN      M. Treumun
# 28     72°15'0.000" W  degrees minutes seconds          NaN      M. Treumun
# 29     71°44'0.000" W  degrees minutes seconds          NaN      M. Treumun
# 34     70°39'2.488" W  degrees minutes seconds          NaN      M. Treumun
# 67     72°18'0.000" W  degrees minutes seconds          NaN      M. Treumun
# 94                NaN                      NaN          NaN     Charif Tala
# 100    80°46'0.000" W  degrees minutes seconds          NaN      M. Treumun
# 107    78°51'0.000" W  degrees minutes seconds          NaN      M. Treumun
#
#     georeferencedDate  georeferenceProtocol georeferenceSources  \
# 18         2018-09-07                   NaN                 NaN
# 21         2018-09-07                   NaN                 NaN
# 28         2018-09-07                   NaN                 NaN
# 29         2018-09-07                   NaN                 NaN
# 34         2018-09-07                   NaN                 NaN
# 67         2018-09-07                   NaN                 NaN
# 94                NaN                   NaN        Google Earth
# 100        2018-09-07                   NaN                 NaN
# 107        2018-09-07                   NaN                 NaN
#
#      georeferenceVerificationStatus     georeferenceRemarks  \
# 18                              NaN  En base a la localidad
# 21                              NaN  En base a la localidad
# 28                              NaN  En base a la localidad
# 29                              NaN  En base a la localidad
# 34                              NaN  En base a la localidad
# 67                              NaN  En base a la localidad
# 94                              NaN                     NaN
# 100                             NaN  En base a la localidad
# 107                             NaN  En base a la localidad
#
#                                        localityid
# 18   DJK/F1K+y0BrVZJC8WqhXXao9psawnd3vgcIBmDwEkM=
# 21   3y8XajQtDujwAH0aRMXw9TlaiVTjUIFoZ3pKML4qLTY=
# 28   VynSmlTthK9N7jVp8xoEWOQzHgn45zpG2QBAG2dYQC8=
# 29   dj2qw/5FanHksCpVG/Jci5vD3Vsyvld74Dg3xXVb3VQ=
# 34   yDNfsPgjmET2GM8++vd4OK+wJqPKUpvBVsYK/JiLO0k=
# 67   Z+pWP41/ZGyg01I+zJfdZUWmeWLEjQb5RUmocDhAIcs=
# 94   4eEDc0BC/RD2KMddqR/tZEaBxbe9xL+WbWwLst9Y4Xo=
# 100  MyUBTfNzm5z0nwL3PkLxvLqv16cWRzWXXgqY6I4rGs0=
# 107  YCgWdFqJbtrW1Yv4keFu6Ld+IpjfOChW5WP7u/oYAoM=

# %%
data
# Out:
#                                                                                        higherGeography  \
# 0                                         South America | Chile | CL | Araucanía | Malleco | Lonquimay
# 1                                                                                                  NaN
# 2                                                                          South-Eastern Pacific Ocean
# 3                                                                          South-Eastern Pacific Ocean
# 4                                                                                                  NaN
# 5                                                                          South-Eastern Pacific Ocean
# 6                                                                                                  NaN
# 7                                                                                                  NaN
# 8                                        South America | Chile | CL | Araucanía | Malleco | Curacautin
# 9                                           South America | Chile | CL | Araucanía | Cautín | Saavedra
# 10                                         South America | Chile | CL | Araucanía | Malleco | Victoria
# 11                                                                                                 NaN
# 12                                                                         South-Eastern Pacific Ocean
# 13                                                                                                 NaN
# 14                                                                                                 NaN
# 15                                                                                                 NaN
# 16                                          South America | Chile | CL | Araucanía | Cautín | Saavedra
# 17                                         South America | Chile | CL | Araucanía | Cautín | Melipeuco
# 18                                            South America | Chile | CL | Araucanía | Cautín | Vilcun
# 19                                                                         South-Eastern Pacific Ocean
# 20                                                                         South-Eastern Pacific Ocean
# 21                                    South America | Chile | CL | Araucanía | Cautín | Nueva Imperial
# 22                                                                                                 NaN
# 23                                                                                                 NaN
# 24                                                                                                 NaN
# 25                                                                                                 NaN
# 26                                                                                                 NaN
# 27                                                                                                 NaN
# 28                                             South America | Chile | CL | Araucanía | Cautín | Cunco
# 29                                       South America | Chile | CL | Araucanía | Malleco | Curacautin
# 30                                                                                                 NaN
# 31                                              South America | Chile | CL | Atacama | Huasco | Huasco
# 32                                                                                                 NaN
# 33                                                                                                 NaN
# 34                                          South America | Chile | CL | Atacama | Chañaral | Chanaral
# 35                                                                                                 NaN
# 36                                                                                                 NaN
# 37                                            South America | Chile | CL | Atacama | Huasco | Vallenar
# 38                                                                                                 NaN
# 39                                              South America | Chile | CL | Atacama | Huasco | Huasco
# 40                                           South America | Chile | CL | Los Lagos | Chiloé | Chonchi
# 41                                           South America | Chile | CL | Los Lagos | Chiloé | Chonchi
# 42                                           South America | Chile | CL | Los Lagos | Palena | Chaiten
# 43                                    South America | Chile | CL | Los Lagos | Llanquihue | LLanquihue
# 44                                          South America | Chile | CL | Los Lagos | Chiloé | Dalcahue
# 45                                             South America | Chile | CL | Los Lagos | Chiloé | Ancud
# 46                                                                                                 NaN
# 47                                                                                                 NaN
# 48                                                                                                 NaN
# 49         South America | South-Eastern Pacific Ocean | Chile | CL | Los Lagos | Llanquihue | Calbuco
# 50                                  South America | Chile | CL | Los Lagos | Llanquihue | Puerto Varas
# 51                                                                                     Océano Pacífico
# 52                                                                                                 NaN
# 53             South America | South-Eastern Pacific Ocean | Chile | CL | Los Lagos | Palena | Chaiten
# 54                                                                                                 NaN
# 55                                                                                                 NaN
# 56                                                                                     Océano Pacífico
# 57                                                                                                 NaN
# 58                                       South America | Chile | CL | Los Lagos | Llanquihue | Calbuco
# 59                                                                                                 NaN
# 60                                                                                                 NaN
# 61                                                                                                 NaN
# 62                                                                                                 NaN
# 63                                       South America | Chile | CL | Los Lagos | Llanquihue | Maullin
# 64                                                                                                 NaN
# 65                                                                                     Océano Pacífico
# 66                                                                                     Océano Pacífico
# 67                                  South America | Chile | CL | Los Lagos | Llanquihue | Puerto Varas
# 68                                                                                                 NaN
# 69                                       South America | Chile | CL | Los Lagos | Llanquihue | Calbuco
# 70                                                                                                 NaN
# 71                                                                                                 NaN
# 72                                                                                                 NaN
# 73                                                                                                 NaN
# 74                                                                                     Océano Pacífico
# 75                                                                                                 NaN
# 76              South America | South-Eastern Pacific Ocean | Chile | CL | Los Lagos | Chiloé | Castro
# 77                                                                                                 NaN
# 78                                                                                                 NaN
# 79                                       South America | Chile | CL | Los Lagos | Llanquihue | Cochamo
# 80                                                                                                 NaN
# 81                                                                                                 NaN
# 82                                                                                                 NaN
# 83                                                                                                 NaN
# 84                                                                                                 NaN
# 85                                                                                                 NaN
# 86                                            South America | Chile | CL | Los Lagos | Osorno | Osorno
# 87                                                                                                 NaN
# 88           South America | South-Eastern Pacific Ocean | Chile | CL | Los Ríos | Valdivia | Valdivia
# 89                                          South America | Chile | CL | Araucanía | Cautín | Loncoche
# 90                                                                                                 NaN
# 91                                                                                                 NaN
# 92                                                                                                 NaN
# 93                                                                                                 NaN
# 94                                                                                                 NaN
# 95                                                                                                 NaN
# 96                                                                         South-Eastern Pacific Ocean
# 97                                                                                                 NaN
# 98                                                                         South-Eastern Pacific Ocean
# 99                                                                                                 NaN
# 100                           South America | Chile | CL | Valparaíso | ísla de Pascua | Ocean Islands
# 101                           South America | Chile | CL | Valparaíso | ísla de Pascua | Ocean Islands
# 102                                                                                                NaN
# 103  South America | South-Eastern Pacific Ocean | Chile | CL | Valparaíso | San Antonio | San Antonio
# 104                              South America | Chile | CL | Valparaíso | San Antonio | Santo Domingo
# 105              South America | Chile | CL | Región Metropolitana de Santiago | Valparaíso | Hijuelas
# 106                                                                                                NaN
# 107                           South America | Chile | CL | Valparaíso | ísla de Pascua | Ocean Islands
# 108                                                                        South-Eastern Pacific Ocean
# 109                                                                                                NaN
#
#                        waterBody      continent country countryCode  \
# 0                            NaN  South America   Chile          CL
# 1                            NaN            NaN     NaN         NaN
# 2    South-Eastern Pacific Ocean            NaN     NaN         NaN
# 3    South-Eastern Pacific Ocean            NaN     NaN         NaN
# 4                            NaN            NaN     NaN         NaN
# 5    South-Eastern Pacific Ocean            NaN     NaN         NaN
# 6                            NaN            NaN     NaN         NaN
# 7                            NaN            NaN     NaN         NaN
# 8                            NaN  South America   Chile          CL
# 9                            NaN  South America   Chile          CL
# 10                           NaN  South America   Chile          CL
# 11                           NaN            NaN     NaN         NaN
# 12   South-Eastern Pacific Ocean            NaN     NaN         NaN
# 13                           NaN            NaN     NaN         NaN
# 14                           NaN            NaN     NaN         NaN
# 15                           NaN            NaN     NaN         NaN
# 16                           NaN  South America   Chile          CL
# 17                           NaN  South America   Chile          CL
# 18                           NaN  South America   Chile          CL
# 19   South-Eastern Pacific Ocean            NaN     NaN         NaN
# 20   South-Eastern Pacific Ocean            NaN     NaN         NaN
# 21                           NaN  South America   Chile          CL
# 22                           NaN  South America   Chile          CL
# 23                           NaN            NaN     NaN         NaN
# 24                           NaN  South America   Chile          CL
# 25                           NaN            NaN     NaN         NaN
# 26                           NaN  South America   Chile          CL
# 27                           NaN            NaN     NaN         NaN
# 28                           NaN  South America   Chile          CL
# 29                           NaN  South America   Chile          CL
# 30                           NaN            NaN     NaN         NaN
# 31                           NaN  South America   Chile          CL
# 32                           NaN            NaN     NaN         NaN
# 33                           NaN            NaN     NaN         NaN
# 34                           NaN  South America   Chile          CL
# 35                           NaN            NaN     NaN         NaN
# 36                           NaN            NaN     NaN         NaN
# 37                           NaN  South America   Chile          CL
# 38                           NaN            NaN     NaN         NaN
# 39                           NaN  South America   Chile          CL
# 40                           NaN  South America   Chile          CL
# 41                           NaN  South America   Chile          CL
# 42                           NaN  South America   Chile          CL
# 43                           NaN  South America   Chile          CL
# 44                           NaN  South America   Chile          CL
# 45                           NaN  South America   Chile          CL
# 46                           NaN            NaN     NaN         NaN
# 47                           NaN            NaN     NaN         NaN
# 48                           NaN            NaN     NaN         NaN
# 49   South-Eastern Pacific Ocean  South America   Chile          CL
# 50                           NaN  South America   Chile          CL
# 51               Océano Pacífico            NaN     NaN         NaN
# 52                           NaN            NaN     NaN         NaN
# 53   South-Eastern Pacific Ocean  South America   Chile          CL
# 54                           NaN            NaN     NaN         NaN
# 55                           NaN            NaN     NaN         NaN
# 56               Océano Pacífico            NaN     NaN         NaN
# 57                           NaN            NaN     NaN         NaN
# 58                           NaN  South America   Chile          CL
# 59                           NaN            NaN     NaN         NaN
# 60                           NaN            NaN     NaN         NaN
# 61                           NaN            NaN     NaN         NaN
# 62                           NaN  South America   Chile          CL
# 63                           NaN  South America   Chile          CL
# 64                           NaN            NaN     NaN         NaN
# 65               Océano Pacífico            NaN     NaN         NaN
# 66               Océano Pacífico            NaN     NaN         NaN
# 67                           NaN  South America   Chile          CL
# 68                           NaN            NaN     NaN         NaN
# 69                           NaN  South America   Chile          CL
# 70                           NaN            NaN     NaN         NaN
# 71                           NaN            NaN     NaN         NaN
# 72                           NaN            NaN     NaN         NaN
# 73                           NaN            NaN     NaN         NaN
# 74               Océano Pacífico            NaN     NaN         NaN
# 75                           NaN            NaN     NaN         NaN
# 76   South-Eastern Pacific Ocean  South America   Chile          CL
# 77                           NaN            NaN     NaN         NaN
# 78                           NaN            NaN     NaN         NaN
# 79                           NaN  South America   Chile          CL
# 80                           NaN  South America   Chile          CL
# 81                           NaN            NaN     NaN         NaN
# 82                           NaN            NaN     NaN         NaN
# 83                           NaN            NaN     NaN         NaN
# 84                           NaN            NaN     NaN         NaN
# 85                           NaN            NaN     NaN         NaN
# 86                           NaN  South America   Chile          CL
# 87                           NaN  South America   Chile          CL
# 88   South-Eastern Pacific Ocean  South America   Chile          CL
# 89                           NaN  South America   Chile          CL
# 90                           NaN            NaN     NaN         NaN
# 91                           NaN            NaN     NaN         NaN
# 92                           NaN            NaN     NaN         NaN
# 93                           NaN            NaN     NaN         NaN
# 94                           NaN            NaN     NaN         NaN
# 95                           NaN  South America   Chile          CL
# 96   South-Eastern Pacific Ocean            NaN     NaN         NaN
# 97                           NaN            NaN     NaN         NaN
# 98   South-Eastern Pacific Ocean            NaN     NaN         NaN
# 99                           NaN  South America   Chile          CL
# 100                          NaN  South America   Chile          CL
# 101                          NaN  South America   Chile          CL
# 102                          NaN            NaN     NaN         NaN
# 103  South-Eastern Pacific Ocean  South America   Chile          CL
# 104                          NaN  South America   Chile          CL
# 105                          NaN  South America   Chile          CL
# 106                          NaN  South America   Chile          CL
# 107                          NaN  South America   Chile          CL
# 108  South-Eastern Pacific Ocean            NaN     NaN         NaN
# 109                          NaN  South America   Chile          CL
#
#                         stateProvince                   county  \
# 0                           Araucanía                  Malleco
# 1                                 NaN                      NaN
# 2                                 NaN                      NaN
# 3                                 NaN                      NaN
# 4                                 NaN                      NaN
# 5                                 NaN                      NaN
# 6                                 NaN                      NaN
# 7                                 NaN                      NaN
# 8                           Araucanía                  Malleco
# 9                           Araucanía                   Cautín
# 10                          Araucanía                  Malleco
# 11                                NaN                      NaN
# 12                                NaN                      NaN
# 13                                NaN                      NaN
# 14                                NaN                      NaN
# 15                                NaN                      NaN
# 16                          Araucanía                   Cautín
# 17                          Araucanía                   Cautín
# 18                          Araucanía                   Cautín
# 19                                NaN                      NaN
# 20                                NaN                      NaN
# 21                          Araucanía                   Cautín
# 22                          Araucanía                  Malleco
# 23                                NaN                      NaN
# 24                          Araucanía                   Cautín
# 25                                NaN                      NaN
# 26                          Araucanía                   Cautín
# 27                                NaN                      NaN
# 28                          Araucanía                   Cautín
# 29                          Araucanía                  Malleco
# 30                                NaN                      NaN
# 31                            Atacama                   Huasco
# 32                                NaN                      NaN
# 33                                NaN                      NaN
# 34                            Atacama                 Chañaral
# 35                                NaN                      NaN
# 36                                NaN                      NaN
# 37                            Atacama                   Huasco
# 38                                NaN                      NaN
# 39                            Atacama                   Huasco
# 40                          Los Lagos                   Chiloé
# 41                          Los Lagos                   Chiloé
# 42                          Los Lagos                   Palena
# 43                          Los Lagos               Llanquihue
# 44                          Los Lagos                   Chiloé
# 45                          Los Lagos                   Chiloé
# 46                                NaN                      NaN
# 47                                NaN                      NaN
# 48                                NaN                      NaN
# 49                          Los Lagos               Llanquihue
# 50                          Los Lagos               Llanquihue
# 51                                NaN                      NaN
# 52                                NaN                      NaN
# 53                          Los Lagos                   Palena
# 54                                NaN                      NaN
# 55                                NaN                      NaN
# 56                                NaN                      NaN
# 57                                NaN                      NaN
# 58                          Los Lagos               Llanquihue
# 59                                NaN                      NaN
# 60                                NaN                      NaN
# 61                                NaN                      NaN
# 62                          Los Lagos               Llanquihue
# 63                          Los Lagos               Llanquihue
# 64                                NaN                      NaN
# 65                                NaN                      NaN
# 66                                NaN                      NaN
# 67                          Los Lagos               Llanquihue
# 68                                NaN                      NaN
# 69                          Los Lagos               Llanquihue
# 70                                NaN                      NaN
# 71                                NaN                      NaN
# 72                                NaN                      NaN
# 73                                NaN                      NaN
# 74                                NaN                      NaN
# 75                                NaN                      NaN
# 76                          Los Lagos                   Chiloé
# 77                                NaN                      NaN
# 78                                NaN                      NaN
# 79                          Los Lagos               Llanquihue
# 80                          Los Lagos               Llanquihue
# 81                                NaN                      NaN
# 82                                NaN                      NaN
# 83                                NaN                      NaN
# 84                                NaN                      NaN
# 85                                NaN                      NaN
# 86                          Los Lagos                   Osorno
# 87                           Los Ríos                 Valdivia
# 88                           Los Ríos                 Valdivia
# 89                          Araucanía                   Cautín
# 90                                NaN                      NaN
# 91                                NaN                      NaN
# 92                                NaN                      NaN
# 93                                NaN                      NaN
# 94                                NaN                      NaN
# 95                         Valparaíso               Valparaíso
# 96                                NaN                      NaN
# 97                                NaN                      NaN
# 98                                NaN                      NaN
# 99                         Valparaíso  San Felipe de Aconcagua
# 100                        Valparaíso           ísla de Pascua
# 101                        Valparaíso           ísla de Pascua
# 102                               NaN                      NaN
# 103                        Valparaíso              San Antonio
# 104                        Valparaíso              San Antonio
# 105  Región Metropolitana de Santiago               Valparaíso
# 106                        Valparaíso               Valparaíso
# 107                        Valparaíso           ísla de Pascua
# 108                               NaN                      NaN
# 109                        Valparaíso                Los Andes
#
#        municipality  islandGroup  island  \
# 0         Lonquimay          NaN     NaN
# 1               NaN          NaN     NaN
# 2               NaN          NaN     NaN
# 3               NaN          NaN     NaN
# 4               NaN          NaN     NaN
# 5               NaN          NaN     NaN
# 6               NaN          NaN     NaN
# 7               NaN          NaN     NaN
# 8        Curacautin          NaN     NaN
# 9          Saavedra          NaN     NaN
# 10         Victoria          NaN     NaN
# 11              NaN          NaN     NaN
# 12              NaN          NaN     NaN
# 13              NaN          NaN     NaN
# 14              NaN          NaN     NaN
# 15              NaN          NaN     NaN
# 16         Saavedra          NaN     NaN
# 17        Melipeuco          NaN     NaN
# 18           Vilcun          NaN     NaN
# 19              NaN          NaN     NaN
# 20              NaN          NaN     NaN
# 21   Nueva Imperial          NaN     NaN
# 22            Puren          NaN     NaN
# 23              NaN          NaN     NaN
# 24        Galvarino          NaN     NaN
# 25              NaN          NaN     NaN
# 26           Temuco          NaN     NaN
# 27              NaN          NaN     NaN
# 28            Cunco          NaN     NaN
# 29       Curacautin          NaN     NaN
# 30              NaN          NaN     NaN
# 31           Huasco          NaN     NaN
# 32              NaN          NaN     NaN
# 33              NaN          NaN     NaN
# 34         Chanaral          NaN     NaN
# 35              NaN          NaN     NaN
# 36              NaN          NaN     NaN
# 37         Vallenar          NaN     NaN
# 38              NaN          NaN     NaN
# 39           Huasco          NaN     NaN
# 40          Chonchi          NaN     NaN
# 41          Chonchi          NaN     NaN
# 42          Chaiten          NaN     NaN
# 43       LLanquihue          NaN     NaN
# 44         Dalcahue          NaN     NaN
# 45            Ancud          NaN     NaN
# 46              NaN          NaN     NaN
# 47              NaN          NaN     NaN
# 48              NaN          NaN     NaN
# 49          Calbuco          NaN     NaN
# 50     Puerto Varas          NaN     NaN
# 51              NaN          NaN     NaN
# 52              NaN          NaN     NaN
# 53          Chaiten          NaN     NaN
# 54              NaN          NaN     NaN
# 55              NaN          NaN     NaN
# 56              NaN          NaN     NaN
# 57              NaN          NaN     NaN
# 58          Calbuco          NaN     NaN
# 59              NaN          NaN     NaN
# 60              NaN          NaN     NaN
# 61              NaN          NaN     NaN
# 62          Calbuco          NaN     NaN
# 63          Maullin          NaN     NaN
# 64              NaN          NaN     NaN
# 65              NaN          NaN     NaN
# 66              NaN          NaN     NaN
# 67     Puerto Varas          NaN     NaN
# 68              NaN          NaN     NaN
# 69          Calbuco          NaN     NaN
# 70              NaN          NaN     NaN
# 71              NaN          NaN     NaN
# 72              NaN          NaN     NaN
# 73              NaN          NaN     NaN
# 74              NaN          NaN     NaN
# 75              NaN          NaN     NaN
# 76           Castro          NaN     NaN
# 77              NaN          NaN     NaN
# 78              NaN          NaN     NaN
# 79          Cochamo          NaN     NaN
# 80     Puerto Montt          NaN     NaN
# 81              NaN          NaN     NaN
# 82              NaN          NaN     NaN
# 83              NaN          NaN     NaN
# 84              NaN          NaN     NaN
# 85              NaN          NaN     NaN
# 86           Osorno          NaN     NaN
# 87         Valdivia          NaN     NaN
# 88         Valdivia          NaN     NaN
# 89         Loncoche          NaN     NaN
# 90              NaN          NaN     NaN
# 91              NaN          NaN     NaN
# 92              NaN          NaN     NaN
# 93              NaN          NaN     NaN
# 94              NaN          NaN     NaN
# 95     Vina del Mar          NaN     NaN
# 96              NaN          NaN     NaN
# 97              NaN          NaN     NaN
# 98              NaN          NaN     NaN
# 99        Rinconada          NaN     NaN
# 100   Ocean Islands          NaN     NaN
# 101   Ocean Islands          NaN     NaN
# 102             NaN          NaN     NaN
# 103     San Antonio          NaN     NaN
# 104   Santo Domingo          NaN     NaN
# 105        Hijuelas          NaN     NaN
# 106      Valparaiso          NaN     NaN
# 107   Ocean Islands          NaN     NaN
# 108             NaN          NaN     NaN
# 109       Los Andes          NaN     NaN
#
#                                                                 locality  \
# 0                        Lagunita en Ruta 181, 6 km al Este de Lonquimay
# 1                                                          R.F. Niblinto
# 2                                                                Carahue
# 3                                                                Carahue
# 4                                                          P.N. Tolhuaca
# 5                                                                Carahue
# 6                                                               La Fusta
# 7                                                               Niblinto
# 8                                                   PN Tolhuaca, sendero
# 9                                            Lago Budi - Romopulli Huapi
# 10                                                        Laguna Malleco
# 11                            Reserva Forestal Niblinto, Sector Niblinto
# 12                                                               Carahue
# 13                                                            Curacautin
# 14                                                            Nahuelbuta
# 15                                               Lago Galletué, Quilquén
# 16                                                Lago Budi - Deume Este
# 17                          Parque Nacional Conguillío - Laguna Arcoiris
# 18                                                         Cautin: Cunco
# 19                                                               Carahue
# 20                                                               Carahue
# 21                                               Cautin: Padre Las Casas
# 22                                            Monumento Natural Contulmo
# 23                                                              Contulmo
# 24                                                                   NaN
# 25        Parque Nacional Tolhuaca, en cerros al norte de Laguna Malleco
# 26                                                              Truftruf
# 27                                                             Lonquimay
# 28                                                    Cautin: Trailanqui
# 29                                           Malleco: Termas De Tolhuaca
# 30                                                           Las Lomitas
# 31                                                           Huasco Bajo
# 32                                  South Of Chañaral, South Of Barquito
# 33                                                       S. Puerto Viejo
# 34        Entry To Pan De Azucar Parque Nacional From Ruta 5 Norte 276 M
# 35                                                   Morro Copiapo; 275M
# 36                          Iii Region, P.N.Pan De Azucar, Qda. Castillo
# 37                                                      Cerro Algarrobal
# 38                                                   Lomitas, Mirador, ?
# 39                                                           Huasco Bajo
# 40                                                        Playa de Cucao
# 41                                                        Playa de Cucao
# 42                                     Río Frío, Tramo Yelcho a La Junta
# 43                                                             Frutillar
# 44                                                               Pelluco
# 45                                                                Pargua
# 46                                                         Volcán Osorno
# 47                                                        Camino a Chepu
# 48                                                                 Ancud
# 49                                                               Calbuco
# 50           Lago Llanquihue - bahía norte Totoral, hay una piscicultura
# 51                                                           Canal Lemuy
# 52                                                      Cerros de Huelde
# 53                                    Fiordo Comau, Huinay, Punta Gruesa
# 54                                            alrededores de Alto Palena
# 55                                             Cipresal Norte de Chaitén
# 56                                                        Canal Dalcahue
# 57                                                        Camino Calbuco
# 58                                              Puerto Montt - costanera
# 59                                                            Huellelhue
# 60                                                        Frutillar bajo
# 61                                            Chaiten, cipresal al Norte
# 62                                                                   NaN
# 63                                                                Chacao
# 64                                                        Cerca de Ancud
# 65                                                          Canal Laitec
# 66                                                       Canal San Pedro
# 67                       Llanquihue: Parque V Perez Rosales, Punta Guano
# 68                                                             Pichicolo
# 69                                                    Bahía Puerto Montt
# 70                                                              Ensenada
# 71                                                       Camino a Ñapeco
# 72                                              Camino a Puerto Cardenas
# 73                                                       Puerto Cardenas
# 74                                                            B. Chaiten
# 75                                                                Osorno
# 76                                                                Chilo‚
# 77                                                Alto Palena. El Malito
# 78   Parque Nacional Vicente Peréz Rosales, Sendero Las Chauras, Cayutué
# 79                                                              Cahuelmó
# 80                                                                   NaN
# 81                                                       Frutillar. CEFF
# 82                                               Parque Nacional Puyehue
# 83                                                            Tepuhueico
# 84                                                              Valdivia
# 85                                                       Mallin de Amaro
# 86                                                            Llancacura
# 87                                                                   NaN
# 88                                                              Valdivia
# 89                                     Lago Panguipulli - sector poblado
# 90                                                   Pendiente de Yunque
# 91                                                        PN. La Campana
# 92                                                                   NaN
# 93                                                             Cartagena
# 94                                                       Laguna El Peral
# 95                                                                   NaN
# 96                                                       Quintay-Tunquén
# 97                                         Estero San Jeronimo. Humedal.
# 98                                                        Isla de Pascua
# 99                                                           La Placilla
# 100                                          Masafuera, Quebrada Sanchez
# 101                                                 Isla Robinson Crusoe
# 102                                                      Limache, Parque
# 103                                              Las Salinas, Las Cruces
# 104                                                 Sector Yali - Camino
# 105              Ocoa, Parque Nacional La Campana, ingreso sector casino
# 106                                                          Playa Ancha
# 107                                    Masatierra, Qda Piedra Agujereada
# 108                                                            El Quisco
# 109                                                           Río Blanco
#
#                                                    verbatimLocality  \
# 0                                                               NaN
# 1                                                     R.F. Niblinto
# 2                                                               NaN
# 3                                                               NaN
# 4                                                     P.N. Tolhuaca
# 5                                                               NaN
# 6                                                          La Fusta
# 7                                                          Niblinto
# 8                                                               NaN
# 9                                                               NaN
# 10                                                              NaN
# 11                                   R. F. Malleco, sector Niblinto
# 12                                                              NaN
# 13                                                       Curacautin
# 14                                                       Nahuelbuta
# 15                                          Lago Galletué, Quilquén
# 16                                                              NaN
# 17                                                              NaN
# 18                                                    Cautin: Cunco
# 19                                                              NaN
# 20                                                              NaN
# 21                                          Cautin: Padre Las Casas
# 22                                                Malleco, Contulmo
# 23                                                         Contulmo
# 24                                                Malleco, Traiguen
# 25                                                    P.N. Tolhuaca
# 26                                                Cautín, Truf Truf
# 27                                                        Lonquimay
# 28                                               Cautin: Trailanqui
# 29                                      Malleco: Termas De Tolhuaca
# 30                                                      Las Lomitas
# 31                                                              NaN
# 32                             South Of Chañaral, South Of Barquito
# 33                                                  S. Puerto Viejo
# 34   Entry To Pan De Azucar Parque Nacional From Ruta 5 Norte 276 M
# 35                                              Morro Copiapo; 275M
# 36                     Iii Region, P.N.Pan De Azucar, Qda. Castillo
# 37                                                 Cerro Algarrobal
# 38                                              Lomitas, Mirador, ?
# 39                                                              NaN
# 40                                                              NaN
# 41                                                              NaN
# 42                                                              NaN
# 43                                                        Frutillar
# 44                                                              NaN
# 45                                                              NaN
# 46                                        Llanquihue, Volcán Osorno
# 47                                                   Camino a Chepu
# 48                                                            Ancud
# 49                                                              NaN
# 50                                                              NaN
# 51                                                              NaN
# 52                                                 Cerros de Huelde
# 53                                                              NaN
# 54                                       alrededores de Alto Palena
# 55                                        Cipresal Norte de Chaitén
# 56                                                              NaN
# 57                                                   Camino Calbuco
# 58                                                              NaN
# 59                                                       Huellelhue
# 60                                                   Frutillar bajo
# 61                                       Chaiten, cipresal al Norte
# 62                                              Llanquihue, Calbuco
# 63                                                              NaN
# 64                                                   Cerca de Ancud
# 65                                                              NaN
# 66                                                              NaN
# 67                  Llanquihue: Parque V Perez Rosales, Punta Guano
# 68                                                        Pichicolo
# 69                                                              NaN
# 70                                                         Ensenada
# 71                                                  Camino a Ñapeco
# 72                                         Camino a Puerto Cardenas
# 73                                                  Puerto Cardenas
# 74                                                              NaN
# 75                                                           Osorno
# 76                                                              NaN
# 77                                           Alto Palena. El Malito
# 78                                       P.N. Vicente Pérez Rosales
# 79                                                              NaN
# 80                                                     Puerto Montt
# 81                                                  Frutillar. CEFF
# 82                                                    P. N. Puyehue
# 83                                                       Tepuhueico
# 84                                                         Valdivia
# 85                                                  Mallin de Amaro
# 86                                                       Llancacura
# 87                                                 Valdivia, Corral
# 88                                                              NaN
# 89                                                              NaN
# 90                                  Juan Fernández, Robinson Crusoe
# 91                                                   PN. La Campana
# 92                                                              NaN
# 93                                                        Cartagena
# 94                                                              NaN
# 95                              Valparaíso, Quintero, Los Arrayanes
# 96                                                              NaN
# 97                                    Estero San Jeronimo. Humedal.
# 98                                                              NaN
# 99                                          Valparaíso, La Placilla
# 100                                     Masafuera, Quebrada Sanchez
# 101                                                             NaN
# 102                                                 Limache, Parque
# 103                                                             NaN
# 104                                                             NaN
# 105                                                             NaN
# 106                                         Valparaíso, Playa Ancha
# ...
# 34                                                                                                          En base a la localidad
# 35                                                                                                          En base a la localidad
# 36                                                                                                          En base a la localidad
# 37                                            Localidad Georreferenciada con Directorios de localidades. Impresición del especimén
# 38                                                                                                          En base a la localidad
# 39                                                                                                                             NaN
# 40                                                                                                                             NaN
# 41                                                                                                                             NaN
# 42                                                                                                                             NaN
# 43                                                                                                                             NaN
# 44                                                                                                                             NaN
# 45                                                                                                                             NaN
# 46   Georreferenciado a través de GeoNames, Geolocate,DICES y Google Earth a nivel más detallado indicado en campo higherGeography
# 47                                                                                                                             NaN
# 48                                                                                                                             NaN
# 49                                                                                                                             NaN
# 50                                                                                                                             NaN
# 51                                                                                                                             NaN
# 52                                                                                                                             NaN
# 53                                                                                                                             NaN
# 54                                                                                                                             NaN
# 55                                                                                                                             NaN
# 56                                                                                                                             NaN
# 57                                                                                                                             NaN
# 58                                                                                                                             NaN
# 59                                                                                                                             NaN
# 60                                                                                                                             NaN
# 61                                                                                                                             NaN
# 62   Georreferenciado a través de GeoNames, Geolocate,DICES y Google Earth a nivel más detallado indicado en campo higherGeography
# 63                                                                                                                             NaN
# 64                                                                                                                             NaN
# 65                                                                                                                             NaN
# 66                                                                                                                             NaN
# 67                                                                                                          En base a la localidad
# 68                                                                                                                             NaN
# 69                                                                                                                             NaN
# 70                                                                                                                             NaN
# 71                                                                                                                             NaN
# 72                                                                                                                             NaN
# 73                                                                                                                             NaN
# 74                                                                                                                             NaN
# 75                                                                                                                             NaN
# 76                                                                                                                             NaN
# 77                                                                                                                             NaN
# 78                                                                                                                             NaN
# 79                                                                                                                             NaN
# 80   Georreferenciado a través de GeoNames, Geolocate,DICES y Google Earth a nivel más detallado indicado en campo higherGeography
# 81                                                                                                                             NaN
# 82                                                                                                                             NaN
# 83                                                                                                                             NaN
# 84                                                                                                                             NaN
# 85                                                                                                                             NaN
# 86                                            Localidad Georreferenciada con Directorios de localidades. Impresición del especimén
# 87   Georreferenciado a través de GeoNames, Geolocate,DICES y Google Earth a nivel más detallado indicado en campo higherGeography
# 88                                                                                                                             NaN
# 89                                                                                                                             NaN
# 90                                                                                                                             NaN
# 91                                                                                                                             NaN
# 92                                                                                                                             NaN
# 93                                                                                                                             NaN
# 94                                                                                                                             NaN
# 95   Georreferenciado a través de GeoNames, Geolocate,DICES y Google Earth a nivel más detallado indicado en campo higherGeography
# 96                                                                                                                             NaN
# 97                                                                                                                             NaN
# 98                                                                                                                             NaN
# 99   Georreferenciado a través de GeoNames, Geolocate,DICES y Google Earth a nivel más detallado indicado en campo higherGeography
# 100                                                                                                         En base a la localidad
# 101                                                                                                                            NaN
# 102                                                                                                                            NaN
# 103                                                                                                                            NaN
# 104                                                                                                                            NaN
# 105                                                                                                                            NaN
# 106  Georreferenciado a través de GeoNames, Geolocate,DICES y Google Earth a nivel más detallado indicado en campo higherGeography
# 107                                                                                                         En base a la localidad
# 108                                                                                                                            NaN
# 109  Georreferenciado a través de GeoNames, Geolocate,DICES y Google Earth a nivel más detallado indicado en campo higherGeography
#
#                                        localityid
# 0    TxmVXS0HuObUcicDzF9JBaWNHK4C/tiPdf9jxpTLMqU=
# 1    WRYd0YGi5ik2bvvJRhC1Ynf4OyfzirN66qbhuD3Fgfc=
# 2    TtMBF2hQMfzrgMVqyIbTHRP0UF9v4Qn8uNonMtuye/s=
# 3    gSE0qlewC1j4UoKOU2+A5amKtzc1j/I5h2bhjv2d+Q8=
# 4    Tw11N7qFI/XzbJam2Z1HHIoLjzOfoRsDpZEPw5+W4tU=
# 5    En2a0PyVD7aactcJD76RHyDU8sr/h1A0JJMRO3G3aZs=
# 6    SjGfyCIgmOvy0/TRjLyF0Pvc7GHh+wJlKN42igGQvg0=
# 7    FcxK8Xhw1Ou0WSDHlOhtlKBTrdsnxeqxolqtNEjue0E=
# 8    ptH/BjpA8L3Ks1Xb3MZQT2eIuLgx0KW2Y9hwASH1+PY=
# 9    2bt8LTmCaBOsLwJpKal7zLTWNNp0URLWyq13fBgx4ow=
# 10   YepvDfOgyVoZBglasd0fnvScyBMlNKDGv6MHE84E1p8=
# 11   PfiPcm7C4UIRgTjwbMoLsxHeojPjklifQABruH+u28A=
# 12   N3LSxKC/WP3dGNu0TmmBzfZZr7K19zF3UFNagaB5xc0=
# 13   TNmgU1cKKcK2hfZLGR3y6nGtpsa4xuGp1UKW40hHqvY=
# 14   NZtz2d/1pV8TSPCmifDjmkG+5/7JmdCJsvZo37P3GYY=
# 15   bjgWdKi3to4pkDqNVWyoQJG/iUd0G713TzR88V93Vco=
# 16   sSal8KGr62LuojS2d/Oy+xrC3cFQY/sFnaIcHe6n9n4=
# 17   Dzdk9HoybCfTTxqwUrJ6dHbJSDK7QuJTZqLOIPxiaXo=
# 18   DJK/F1K+y0BrVZJC8WqhXXao9psawnd3vgcIBmDwEkM=
# 19   Fnm98+2XJwenDSTADw/JUpp3S8PvKsMNAg5khKpZSZU=
# 87   V/x7nXxJ49M6hPKtC8h/YBxOUBgWvdkWU1prD6aI2Wo=
# 88   1ApulJ6JbFSOKHiWV/aQMzgY7p7W/ztFKVwGy4NYtYk=
# 89   31fx5jZKXafRNIBw7DJD9+V7iN5WvHPKG5QB3K+csiY=
# 90   62J+tWGxYIAKRu3npiUOa86K916U2xeo5z+lSH+SPRY=
# 91   66cQwErCEFkEbxhdiFNIh1GFxau3a5B74m0Th0pdUVs=
# 92   dIVBvGPaU2swqnMwPdCGpUdhoiuM7vITB5ZGaNHTMvY=
# 93   0aULcAJDQ8hnboftpurXKbKZKJ9hyWxdabsFCoBzhWU=
# 94   4eEDc0BC/RD2KMddqR/tZEaBxbe9xL+WbWwLst9Y4Xo=
# 95   D04k27DfNh8NueOkh0ImHutY0gXMsguq6CsFxFDvI/Y=
# 96   fLC6XA+RzqAqzb8EibMx38XTaslEU32ltdsq38dMmGs=
# 97   3q7RzEIet+YH+EX4QsdTSl5r+2mV5VyNpgVzIaFwcpo=
# 98   NS72U5FxpkM1Z0H3JKaarNldGGtffWx9gXXTqzcDL98=
# 99   c1N2ULzlrKMfpBPYqJPjXg8ca/7oG1cfQDOGkIrN8zc=
# 100  MyUBTfNzm5z0nwL3PkLxvLqv16cWRzWXXgqY6I4rGs0=
# 101  whqG5foV2xOnnMueskw9Ue9HlzFEZL+b5NLsC65pHVg=
# 102  CrT9pu1BBSZUJaNI6AtcS/sABFprRxTfvahCrrXpCJg=
# 103  WMVGT6x3X8QelVT2vrK8VfHJgRtYzIzqwfotW1gyeKc=
# 104  Dzbd6WTD6UBTBOiNrBe0v9Gv6/43mnduOr2X1PYAZdI=
# 105  rbPp7LlP8R78/VBHQiWfqA51+qeeu62rJ8XODXqBm/c=
# 106  HVoHXv8ifqVeUCAYhiDRTuyKmqixjppKV3bwVx7MAbw=
# 107  YCgWdFqJbtrW1Yv4keFu6Ld+IpjfOChW5WP7u/oYAoM=
# 108  /0h1tIuArvSEx1ktY3JjnXCcHGrefNvWljHHsTqfcAs=
# 109  0pjicG7PG7L8583buCEHxwZEMaMUaysKt+Cjr4B+Edk=

# %%
driver.quit()

# %% [markdown]
# # Find Country Test

# %%
import requests

result=requests.get(f"https://api.gbif-uat.org/v1/geocode/reverse?lat=-38.8464&lng=-73.7889").json()
result
# Out:
# [{'id': 'http://marineregions.org/mrgid/8465',
#   'type': 'EEZ',
#   'source': 'http://vliz.be/vmdcdata/marbound/',
#   'title': 'Chilean Exclusive Economic Zone',
#   'isoCountryCode2Digit': 'CL',
#   'distance': 0.0},
#  {'id': 'http://marineregions.org/mrgid/1910',
#   'type': 'IHO',
#   'source': 'http://marineregions.org/',
#   'title': 'South Pacific Ocean',
#   'isoCountryCode2Digit': None,
#   'distance': 0.0},
#  {'id': 'http://vocab.nerc.ac.uk/collection/C19/current/SVX00022/',
#   'type': 'SeaVoX',
#   'source': 'http://marineregions.org/',
#   'title': 'SOUTHEAST PACIFIC OCEAN (140W)',
#   'isoCountryCode2Digit': None,
#   'distance': 0.0}]
